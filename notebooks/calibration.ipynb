# %% [markdown]
# # Calibration

# %% [markdown]
# #### Before we can make any sort of future predicitions, we first need a robust set of tools to analyse available historical data. Here, we implement optimised methods to produce useful mean and variance data for our stochastic models. We won't go into code as it's all going on in the background and will basically never be called by you, the user.

# %% [markdown]
# ![Stock progression](../img/examplestockprogression.png)

# %% [markdown]
# Above is an example of the progression of a stock. its pretty cool and all but a better metric is return or % change between ticks (individual measurements). Furthermore we use a logarithmic scale as is required for monte carlo simulations. This is because (cool explanation pending). This leads to the following graph in green.

# %% [markdown]
# ![Returns progression](../img/examplereturnsprogression.png)

# %% [markdown]
# while we obviously could use normal covariance, this is clunky in the real world so we use exponentially weighted moving average covariance (EWMA). This places a greater importance on recent stock performance so as to be more responsive in case of sudden change, as well as more quickly settle into normality afterwards.
#
# $Cov ≈ (1-λ) * Σ_{i=0}^{T-1} λ^i * (r_{t-i}-μ)(r_{t-i}-μ)^T$

# %% [markdown]
# explain covariance matrix?

# %% [markdown]
# now we should also mention shrinkage in the covariant matrix

# %% [markdown]
# HERE is where we have a big graph showing a stress test with each improvement leading to better predictions overall in an overlay line graph.

# %% [markdown]
# now we have scalable data type thats optimised and easy to work with and have used to to produce optimised statistical variables for our simulations
